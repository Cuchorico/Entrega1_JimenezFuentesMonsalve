# %% [markdown]
# <a href="https://colab.research.google.com/github/Cuchorico/Entrega1_JimenezFuentesMonsalve/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

cuba = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Presupuesto Estatal de Cuba anual.csv" , sep=";" , encoding="latin-1")

print (cuba["Unnamed: 3"][20:26])
print (cuba["Unnamed: 8"][-2:])
# Out:
# 20       Cultura y Deportes
# 21      $67.993.233.000,00
# 22      $82.360.817.000,00
# 23      $97.882.939.000,00
# 24     $241.856.846.000,00
# 25     $439.916.708.000,00
# Name: Unnamed: 3, dtype: object
# 26    NaN
# 27    NaN
# Name: Unnamed: 8, dtype: object

# %%
Presupuestodecuba
# Out:
#                             ï»¿VALOR EN PESOS CUBANOS  \
# 0                      Miles de Millones de $ cubanos
# 1                                                2018
# 2                                                2019
# 3                                                2020
# 4                                                2021
# 5                                                2022
# 6                                                 NaN
# 7    *=estimaciÃ³n en base a lo presupuestado en l...
# 8                                                 NaN
# 9                  VALOR EN MILES DE MILLONES CUBANOS
# 10                     Miles de Millones de $ cubanos
# 11                                               2018
# 12                                               2019
# 13                                               2020
# 14                                               2021
# 15                                               2022
# ...
